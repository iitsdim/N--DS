# %% [markdown]
# # Instructions

# %% [markdown]
# Вам выдано 2 датасета:
# - P04_TRAIN.pq (train)
# - P04_TEST.pq (test)
#
# Вам необходимо обучить модель на данных из **train**, и проскорить датасет **test**.
#
# Это задача на *бинарную* классификацию, с *дисбалансированными* классами.
# Вам доступны *любые* библиотеки и инструменты, которые есть на python.
#
# **<span style='color:red'> !!! </span>** Так же необходимо оформлять ноутбук и стараться комментировать коды в каждом этапе решения задачи **<span style='color:red'> !!! </span>**
#
# После скоринга, вам необходимо отправить проскоренный .csv файл в формате, и ноутбук с решением (можно и ссылку в collab):
# **[ID, predicted]**

# %% [markdown]
# # Начало проекта

# %%
import pandas as pd

# %%
df_train = pd.read_parquet('P04_TRAIN.pq')
df_test  = pd.read_parquet('P04_TEST.pq')

# %%
df_train
# Out:
#                   ID  TARGET  FEATURE_1  FEATURE_2  FEATURE_3  FEATURE_4
# 0      1-33725273547       0   0.604733   0.303755   0.001755   0.291645  \
# 1      1-33165158948       0   0.730506   4.031284   0.000106   2.883802
# 2      1-33270455953       0   0.000032   0.774739   0.000010   7.657499
# 3      1-32934335615       0   1.647914   5.325781   0.001407   6.557573
# 4      1-34112605832       0   3.891732   4.414761   0.080974   3.016513
# ...              ...     ...        ...        ...        ...        ...
# 20133  1-33194268837       0   0.000000   4.755190   0.000000   0.348208
# 20134  1-33493779388       0   0.326693   6.469571   0.032283  23.842242
# 20135  1-34046404092       0   0.349497   0.764158   0.000229   5.766869
# 20136  1-34345700658       0   0.091942   0.187871   0.000000   3.402073
# 20137  1-33449984445       0   0.934653   0.737914   0.000530  23.119934
#
#        FEATURE_5  FEATURE_6  FEATURE_7  FEATURE_8  ...  FEATURE_405
# 0       0.101433   4.995094        0.0   0.000000  ...          NaN  \
# 1       0.485855   0.000000        0.0   0.000000  ...          NaN
# 2       0.138511   4.102084        0.0   1.285695  ...          NaN
# 3       0.376410  15.120202        0.0   0.000000  ...          NaN
# 4       1.943187   2.387400        0.0   0.000000  ...          NaN
# ...          ...        ...        ...        ...  ...          ...
# 20133   0.198604   3.159066        0.0   0.127652  ...          NaN
# 20134   6.409096   1.856867        0.0   0.000000  ...          NaN
# 20135   0.070918   2.970987        0.0   0.000000  ...          NaN
# 20136   0.852378   1.379387        0.0   0.000000  ...          NaN
# 20137   1.221969   5.430009        0.0   0.067660  ...          NaN
#
#        FEATURE_406  FEATURE_407  FEATURE_408  FEATURE_409  FEATURE_410
# 0              NaN          NaN          NaN         -1.0         -1.0  \
# 1              NaN          NaN          NaN         -1.0         -1.0
# 2              NaN   560.321126   560.211151         -1.0         -1.0
# 3              NaN          NaN          NaN         -1.0         -1.0
# 4              NaN   726.932805   726.932805         -1.0         -1.0
# ...            ...          ...          ...          ...          ...
# 20133          NaN   854.613439   854.613439         -1.0         -1.0
# 20134          NaN     0.000000     0.000000         -1.0         -1.0
# 20135          NaN          NaN          NaN         -1.0         -1.0
# 20136          NaN          NaN          NaN         -1.0         -1.0
# 20137          NaN   637.413395     0.000000         -1.0         -1.0
#
#        FEATURE_411  FEATURE_412  FEATURE_413  FEATURE_414
# 0             None         -1.0          NaN          NaN
# 1             None         -1.0          NaN          NaN
# 2             None         -1.0          NaN          NaN
# 3             None         -1.0          NaN          NaN
# 4             None         -1.0          NaN          NaN
# ...            ...          ...          ...          ...
# 20133         None         -1.0          NaN          NaN
# 20134         None         -1.0          NaN          NaN
# 20135         None         -1.0          NaN          NaN
# 20136         None         -1.0          NaN          NaN
# 20137         None         -1.0          NaN          NaN
#
# [20138 rows x 416 columns]

# %%
df_train['TARGET'].value_counts()
# Out:
# TARGET
# 0    20000
# 1      138
# Name: count, dtype: int64

# %%
df_train.columns
# Out:
# Index(['ID', 'TARGET', 'FEATURE_1', 'FEATURE_2', 'FEATURE_3', 'FEATURE_4',
#        'FEATURE_5', 'FEATURE_6', 'FEATURE_7', 'FEATURE_8',
#        ...
#        'FEATURE_405', 'FEATURE_406', 'FEATURE_407', 'FEATURE_408',
#        'FEATURE_409', 'FEATURE_410', 'FEATURE_411', 'FEATURE_412',
#        'FEATURE_413', 'FEATURE_414'],
#       dtype='object', length=416)
